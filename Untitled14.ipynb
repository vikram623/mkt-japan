# %% [markdown]
# <a href="https://colab.research.google.com/github/vikram623/mkt-japan/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Today i am learing practical implemention of statistics with python")
# Out:
# Today i am learing practical implemention of statistics with python

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mtp
import statistics as st

# %%
ages=[20,23,24,18,20,23,28,27,29,40,150,23]
print("mean: ",np.mean(dataset))
print("median: ",np.median(dataset))
print("mode: ",st.mode(dataset))
# Out:
# mean:  37.9
# median:  25.5
# mode:  23

# %%
# finding the outliyers from the dataset
import seaborn as sns

# %%
sns.boxplot(ages)
# Out:
# <Axes: >

# %%
# five number summary
q1,q3=np.percentile(ages,[25,75])

# %%
print("q1 ",q1)
print("q3 ",q3)
# Out:
# q1  22.25
# q3  28.25

# %%
# to check outliyers [lower fens ,higher fens]
iqr=q3-q1
lower_fens=q1-1.5*(iqr)
higher_fens=q3+1.5*(iqr)
print(lower_fens,higher_fens)
# Out:
# 13.25 37.25

# %%
print(st.variance(ages))
print(np.var(ages))
# Out:
# 1335.3560606060605
# 1224.076388888889

# %%
import math as mt

# %%
# find standard deviation
stdv=mt.sqrt(st.variance(ages))
print(stdv)
# Out:
# 36.542524004316675

# %%
print(sns.histplot(ages))
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
# probability density function
print(sns.histplot(ages,kde=True))
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
# now we are working with practical dataset
df=sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.histplot(df['sepal_length'],kde=True)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(df['sepal_width'],kde=True)
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(df['petal_length'],kde=True)
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(df['petal_width'],kde=True)
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
s=np.random.normal(0.5,0.2,1000)
s
# Out:
# array([ 0.63827524,  0.18467184,  0.60479455,  0.57798306,  0.54171229,
#         0.50588807,  0.40326863,  0.33846493,  0.2430113 ,  0.38204985,
#         0.32320763,  0.555751  ,  0.37809592,  0.63838519,  0.30262964,
#         0.63105251,  0.55459644,  0.6978909 ,  0.27114979,  0.60627483,
#         0.36136121,  0.54657639,  0.67639862,  0.84987161,  0.61409835,
#         0.65352325,  0.60669914,  0.45705371,  0.1898959 ,  0.62754837,
#         0.75166647,  0.20378785,  0.10135861,  0.66711669,  0.32952041,
#         0.42110177,  0.47577364,  0.29066604,  0.79532563,  0.75139162,
#         0.51462474,  0.25526826,  0.69282111,  0.50026789,  0.48972986,
#         0.62374066,  0.51626723,  0.31237634,  0.60381261,  0.38998105,
#         0.49381906,  0.41882903,  0.55047904,  0.52759973,  0.60009418,
#         0.56985869,  0.82206478,  0.72299827,  0.5007121 ,  0.29087508,
#         0.64874052,  0.62645621,  0.84403301,  0.61281657,  0.7875387 ,
# ...

# %%
sns.histplot(s,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
s=np.random.lognormal(3,1,100)
sns.histplot(s,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(np.log(s),kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
#### If you want to check whether feature is guassian or normal distributed
#### Q-Q plot
import matplotlib.pyplot as plt
import scipy.stats as stat
import pylab
def plot_data(sample):
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    sns.histplot(sample)
    plt.subplot(1,2,2)
    stat.probplot(sample,dist='norm',plot=pylab)
    plt.show()

# %%
## create a normal distributed data
s=np.random.normal(0.5,0.2,1000)
plot_data(s)

# %%
plot_data(df['sepal_width'])

# %%
mu, sigma = 3., 1. # mean and standard deviation
sample = np.random.lognormal(mu, sigma, 100)

# %%
def plot_data_log(sample):
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    sns.histplot(sample)
    plt.subplot(1,2,2)
    stat.probplot(np.log(sample),dist='norm',plot=pylab)
    plt.show()

# %%
plot_data_log(sample)

# %%
df=sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import pandas as pd

# %%
df.corr()
# Out:
# <ipython-input-61-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.pairplot(df)
